# %% [markdown]
# # Linear regression approach to water bottom values
#
# Off-shore seismic data acquisition faces many challenges due to difficult environment the ocean can present. The forces from the tugging ship, the presence of waves,  animals, including growth of barnacles, are all factors playing against the arrays of receivers floating on the ocean surface. These factors tend to lead to failures in the recording equipment which can lead to missing data points. Re-processing data of vintage age can also mean that some important data points might be missing.
#
# Here we study the case where the values of the ocean bottom values have missing points in the recorded values using open source data. We approach the problem via linear regression, and explore which type of regression gives the most satisfactory answer.
#
# We will see the nearest-neighbor approach gives the best result. The kNN case, being non-parametric, exceeds since the ocean bottom is irregular.
#
#
# In the first half of this notebook we work with a single track (about 23 km long) of the vessel's trajectory. In the second half we look at predicting values over several tracks covering a square.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.neighbors import KNeighborsRegressor

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})

# %% [markdown]
# # Part 1: working with one track of data acquisition

# %% [markdown]
# ### Import data and manipulate

# %%
raw_data = pd.read_csv('oneGun_oneCable_seismic_data.csv')

# %%
raw_data.head(4)
# Out:
#    channel_number  shot_number  geophoneDepth  sourceDepth  geophoneDatum  \
# 0             577         1580           10.8          6.0            0.0
# 1             578         1580           10.7          6.0            0.0
# 2             579         1580           10.6          6.0            0.0
# 3             580         1580           10.6          6.0            0.0
#
#    sourceDatum  WBdepth_sourceLocation  WBdepth_geophoneLocation   sourceX  \
# 0          0.0                    37.8                       0.0  522200.2
# 1          0.0                    37.8                       0.0  522200.2
# 2          0.0                    37.8                       0.0  522200.2
# 3          0.0                    37.8                       0.0  522200.2
#
#      sourceY  geophoneX  geophoneY  shipSpeed  day  hour  minute  sec  \
# 0  6617332.3   522170.7  6617404.8        226  265    12      56   22
# 1  6617332.3   522167.7  6617416.9        226  265    12      56   22
# 2  6617332.3   522164.6  6617429.1        226  265    12      56   22
# 3  6617332.3   522161.5  6617441.2        226  265    12      56   22
#
#    streamerNumber
# 0               4
# 1               4
# 2               4
# 3               4

# %%
# plotting the traverse of the ship
raw_data.groupby('sourceY').first().reset_index().plot(x='sourceX',y='sourceY',figsize=(4,8),title='ship trajectory',fontsize=15)

# %% [markdown]
# Let's transform the hour, minute,second columns to one measure of time.

# %%
raw_data['time'] = raw_data['hour']*60*60 + raw_data['minute']*60 + raw_data['sec']

# %% [markdown]
# Note that all of the data in raw_data was acquired the same day. Day = 265 for all observations. Also, gdel and sdel columns are constant. So we get rid of these three columns. We can also get rid of the hour, minute, and sec values since we have the column `time`.

# %%
#checking that column is indeed constant
raw_data['day'].min() == raw_data['day'].max()
# Out:
# True

# %%
raw_data.geophoneDatum.min() == raw_data.geophoneDatum.max()
# Out:
# True

# %%
raw_data.sourceDatum.min() == raw_data.sourceDatum.max()
# Out:
# True

# %% [markdown]
# We will call our final dataframe "relevant_data":

# %%
#dropping irrelevant columns
relevant_data = raw_data.drop(['day','geophoneDatum','sourceDatum','hour','minute','sec'],axis=1).groupby('shot_number').first().reset_index()

# %%
relevant_data.head()
# Out:
#    shot_number  channel_number  geophoneDepth  sourceDepth  \
# 0         1580             577           10.8          6.0
# 1         1596             577           10.8          6.1
# 2         1612             577           10.8          6.0
# 3         1628             577           10.7          6.0
# 4         1644             577           10.7          6.1
#
#    WBdepth_sourceLocation  WBdepth_geophoneLocation   sourceX    sourceY  \
# 0                    37.8                       0.0  522200.2  6617332.3
# 1                    37.8                       0.0  522201.4  6617307.4
# 2                    37.9                       0.0  522202.6  6617282.7
# 3                    38.0                       0.0  522204.0  6617257.2
# 4                    38.1                       0.0  522205.4  6617232.4
#
#    geophoneX  geophoneY  shipSpeed  streamerNumber   time
# 0   522170.7  6617404.8        226               4  46582
# 1   522172.0  6617379.9        226               4  46593
# 2   522173.4  6617355.4        214               4  46605
# 3   522175.0  6617330.2        218               4  46616
# 4   522176.8  6617305.4        219               4  46627

# %%
relevant_data.columns
# Out:
# Index(['shot_number', 'channel_number', 'geophoneDepth', 'sourceDepth',
#        'WBdepth_sourceLocation', 'WBdepth_geophoneLocation', 'sourceX',
#        'sourceY', 'geophoneX', 'geophoneY', 'shipSpeed', 'streamerNumber',
#        'time'],
#       dtype='object')

# %% [markdown]
# We get k-folds for cross-validation:

# %%
kfolds = KFold(n_splits=10,shuffle=False,random_state=0)

# %%
lasso = Lasso(alpha=1,fit_intercept=True,normalize=True,random_state=0)

# %% [markdown]
# ## Modelling WBdepth_sourceLocation (water bottom depth at source)

# %% [markdown]
# Let's plot the water bottom value as a function of the shot number. The water bottom depth is recorded at the location of each shot (source point).

# %%
relevant_data.plot(x='shot_number',y='WBdepth_sourceLocation',figsize=(13,7))

# %%
# we pick the attributes out of the columns in relevant_data:

waterDepthAttributes = ['shot_number', 'channel_number', 'geophoneDepth', 'sourceDepth', 'WBdepth_geophoneLocation', 'sourceX',
       'sourceY', 'geophoneX', 'geophoneY', 'shipSpeed', 'streamerNumber',
       'time']

# %% [markdown]
# Split the data into a testing and training set. The training set will further broken up in cross-validation sets.

# %%
W_train,W_test,w_train,w_test = train_test_split(relevant_data[waterDepthAttributes],relevant_data['WBdepth_sourceLocation'],random_state=0)

# %%
W_train.head()
# Out:
#      shot_number  channel_number  geophoneDepth  sourceDepth  \
# 240         5420             577           10.5          6.0
# 270         5900             577           10.4          6.0
# 747        13532             577           10.2          6.1
# 838        14988             577           10.1          6.1
# 39          2204             577           10.9          6.0
#
#      WBdepth_geophoneLocation   sourceX    sourceY  geophoneX  geophoneY  \
# 240                      0.00  522254.0  6611334.1   522223.2  6611407.5
# 270                      0.00  522239.6  6610583.9   522210.7  6610658.1
# 747                     65.04  522261.9  6598660.5   522253.6  6598739.9
# 838                     61.36  522245.1  6596385.9   522236.2  6596465.4
# 39                       0.00  522246.9  6616358.1   522216.9  6616430.6
#
#      shipSpeed  streamerNumber   time
# 240        210               4  49402
# 270        218               4  49745
# 747        179               4  55724
# 838        187               4  56951
# 39         212               4  47036

# %%
alphaScan_rss_w = []

for Alpha in np.logspace(-3,1,10):
    
    temp_rss = []
    for trainIndex, valIndex in kfolds.split(W_train):
        lasso = Lasso(alpha=Alpha,fit_intercept=True,normalize=True,random_state=0).fit(W_train.iloc[trainIndex,:],w_train.iloc[trainIndex])
        y_pred_val = lasso.predict(W_train.iloc[valIndex,:])
        temp_rss.append(((y_pred_val - w_train.iloc[valIndex])**2).sum())
        if list(np.nonzero(lasso.coef_)[0]):
            print('at alpha =',Alpha, 'the non-zero coefficients are',np.nonzero(lasso.coef_)[0])
        
    
    alphaScan_rss_w.append(np.mean(temp_rss))
# Out:
# at alpha = 0.001 the non-zero coefficients are [0 2 3 4 5 6 7 9]
# at alpha = 0.001 the non-zero coefficients are [0 2 3 4 5 6 7 9]
# at alpha = 0.001 the non-zero coefficients are [0 2 3 4 5 6 7 9]
# at alpha = 0.001 the non-zero coefficients are [0 2 3 4 5 6 7 9]
# at alpha = 0.001 the non-zero coefficients are [0 2 3 4 5 6 7 9]
# at alpha = 0.001 the non-zero coefficients are [0 2 3 4 5 6 7 9]
# at alpha = 0.001 the non-zero coefficients are [0 2 3 4 5 6 7 9]
# at alpha = 0.001 the non-zero coefficients are [0 2 3 4 5 6 7 9]
# at alpha = 0.001 the non-zero coefficients are [0 2 3 4 5 6 7 9]
# at alpha = 0.001 the non-zero coefficients are [0 2 3 4 5 6 7 9]
# at alpha = 0.0027825594022071257 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.0027825594022071257 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.0027825594022071257 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.0027825594022071257 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.0027825594022071257 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.0027825594022071257 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.0027825594022071257 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.0027825594022071257 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.0027825594022071257 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.0027825594022071257 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.007742636826811269 the non-zero coefficients are [2 3 4 5 9]
# at alpha = 0.007742636826811269 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.007742636826811269 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.007742636826811269 the non-zero coefficients are [2 3 4 5 9]
# at alpha = 0.007742636826811269 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.007742636826811269 the non-zero coefficients are [2 3 4 5 9]
# at alpha = 0.007742636826811269 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.007742636826811269 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.007742636826811269 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.007742636826811269 the non-zero coefficients are [0 2 3 4 5 9]
# at alpha = 0.021544346900318832 the non-zero coefficients are [2 3 4 5 9]
# at alpha = 0.021544346900318832 the non-zero coefficients are [2 4 5 9]
# at alpha = 0.021544346900318832 the non-zero coefficients are [2 4 5 9]
# at alpha = 0.021544346900318832 the non-zero coefficients are [2 4 5 9]
# at alpha = 0.021544346900318832 the non-zero coefficients are [2 4 5 9]
# at alpha = 0.021544346900318832 the non-zero coefficients are [2 4 5 9]
# at alpha = 0.021544346900318832 the non-zero coefficients are [2 4 5 9]
# at alpha = 0.021544346900318832 the non-zero coefficients are [2 4 5 9]
# at alpha = 0.021544346900318832 the non-zero coefficients are [2 4 5 9]
# at alpha = 0.021544346900318832 the non-zero coefficients are [2 4 5 9]
# at alpha = 0.05994842503189409 the non-zero coefficients are [2 4 7]
# at alpha = 0.05994842503189409 the non-zero coefficients are [2 4 7]
# at alpha = 0.05994842503189409 the non-zero coefficients are [2 4 7]
# at alpha = 0.05994842503189409 the non-zero coefficients are [2 4 7]
# at alpha = 0.05994842503189409 the non-zero coefficients are [2 4 7]
# at alpha = 0.05994842503189409 the non-zero coefficients are [2 4 7]
# at alpha = 0.05994842503189409 the non-zero coefficients are [2 4 7]
# at alpha = 0.05994842503189409 the non-zero coefficients are [2 4 7]
# at alpha = 0.05994842503189409 the non-zero coefficients are [2 4 7]
# at alpha = 0.05994842503189409 the non-zero coefficients are [2 4 7]
# at alpha = 0.1668100537200059 the non-zero coefficients are [4 7]
# at alpha = 0.1668100537200059 the non-zero coefficients are [2 4 7]
# at alpha = 0.1668100537200059 the non-zero coefficients are [2 4 7]
# at alpha = 0.1668100537200059 the non-zero coefficients are [2 4 7]
# at alpha = 0.1668100537200059 the non-zero coefficients are [2 4 7]
# at alpha = 0.1668100537200059 the non-zero coefficients are [2 4 7]
# at alpha = 0.1668100537200059 the non-zero coefficients are [4 7]
# at alpha = 0.1668100537200059 the non-zero coefficients are [2 4 7]
# at alpha = 0.1668100537200059 the non-zero coefficients are [4 7]
# at alpha = 0.1668100537200059 the non-zero coefficients are [4 7]

# %%
if [1]:
    print(1)
# Out:
# 1

# %%
plt.figure(figsize=(5,5))
plt.plot(np.logspace(-3,1,10),alphaScan_rss_w)
plt.xlim(0,2)
plt.title('RSS(alpha)')
# Out:
# Text(0.5, 1.0, 'RSS(alpha)')

# %% [markdown]
# We plot the path of the coefficients as we vary alpha:

# %%
all_coeffs_w = []
for Alpha in np.logspace(-3,1,20):
    lasso = Lasso(alpha=Alpha, fit_intercept=True, normalize=True, random_state=0).fit(W_train,w_train)
    all_coeffs_w.append(lasso.coef_)

# %%
coeff_path_w = np.array(all_coeffs_w).transpose()

# %%
plt.figure(figsize=(10,8))
for x in range(11):
    plt.plot(np.logspace(-3,1,20),coeff_path_w[x])
plt.xlim(0,.4)
plt.ylim(-0.4,.6)
plt.xlabel('alpha')
plt.ylabel('coefficient value')
plt.title('Coefficient paths')
# Out:
# Text(0.5, 1.0, 'Coefficient paths')

# %% [markdown]
# We choose alpha = 0.01.

# %%
lasso_w = Lasso(alpha=0.01, fit_intercept=True, normalize=True, random_state=0).fit(W_train,w_train)
w_pred_lasso = lasso_w.predict(W_test)
np.argwhere(lasso_w.coef_ > 0)
# Out:
# array([[3],
#        [4],
#        [5],
#        [9]])

# %%
W_train.head(3)
# Out:
#      shot_number  channel_number  geophoneDepth  sourceDepth  \
# 240         5420             577           10.5          6.0
# 270         5900             577           10.4          6.0
# 747        13532             577           10.2          6.1
#
#      WBdepth_geophoneLocation   sourceX    sourceY  geophoneX  geophoneY  \
# 240                      0.00  522254.0  6611334.1   522223.2  6611407.5
# 270                      0.00  522239.6  6610583.9   522210.7  6610658.1
# 747                     65.04  522261.9  6598660.5   522253.6  6598739.9
#
#      shipSpeed  streamerNumber   time
# 240        210               4  49402
# 270        218               4  49745
# 747        179               4  55724

# %% [markdown]
# Lasso is selecting the following attributes: 'ep','selev','sx','sfs'. For other values of alpha 'sy' was also selected so we will include it.

# %%
#lassoSelectedAttr = ['ep','selev','sx','sy','sfs']
lassoSelectedAttr= ['shot_number',  'sourceDepth', 'WBdepth_geophoneLocation', 'sourceX',
       'sourceY',   'streamerNumber',]

# %% [markdown]
# ### Ridge regression and linear regression with selected attributes
#
# With the selected attributes, we employ ridge regression on the same data:

# %%
W_train_selected = W_train[lassoSelectedAttr]
W_test_selected = W_test[lassoSelectedAttr]

# %%
W_test_selected.head()
# Out:
#      shot_number  sourceDepth  WBdepth_geophoneLocation   sourceX    sourceY  \
# 406         8076          6.0                      0.00  522253.7  6607184.1
# 14          1804          6.0                      0.00  522218.9  6616982.8
# 689        12604          6.1                     78.71  522257.8  6600110.7
# 145         3900          5.9                      0.00  522252.7  6613709.4
# 310         6540          6.0                      0.00  522230.9  6609583.8
#
#      streamerNumber
# 406               4
# 14                4
# 689               4
# 145               4
# 310               4

# %%
ridge_w_RSS = []
for Lambda in np.logspace(-4,2):
    
    temp_rss = []
    
    for trainIndex, testIndex in kfolds.split(W_train_selected):
    
        ridge = Ridge(alpha=Lambda, fit_intercept=True, normalize=True,random_state=0).fit(W_train_selected.iloc[trainIndex],w_train.iloc[trainIndex])
        temp_rss.append(((w_train.iloc[testIndex] - ridge.predict(W_train_selected.iloc[testIndex]))**2 ).sum())
    
    ridge_w_RSS.append(np.mean(temp_rss))

# %%
plt.figure(figsize=(8,8))
plt.plot(np.logspace(-4,2),ridge_w_RSS)
plt.title('RSS(lambda)')
# Out:
# Text(0.5, 1.0, 'RSS(lambda)')

# %% [markdown]
# Let's look at the path of the coefficients

# %%
ridge_coeff = []
for Lambda in np.logspace(-4,2):
    ridge =  Ridge(alpha=Lambda, fit_intercept=True, normalize=True,random_state=0).fit(W_train_selected.iloc[trainIndex],w_train.iloc[trainIndex])
    ridge_coeff.append(ridge.coef_)

# %%
ridge_coeff_path = np.array(ridge_coeff).transpose()

# %%
plt.figure(figsize=(5,5))
for x in range(5):
    plt.plot(np.logspace(-3,2),ridge_coeff_path[x])
plt.ylim(0,4)
plt.title('coefficients path')
plt.xlabel('lambda')
plt.ylabel('coefficient value')
# Out:
# Text(0, 0.5, 'coefficient value')

# %% [markdown]
# Zooming in:

# %%
plt.figure(figsize=(5,5))
for x in range(5):
    plt.plot(np.logspace(-3,2),ridge_coeff_path[x])
plt.ylim(0,.02)
# Out:
# (0, 0.02)

# %% [markdown]
# We can see from the above plots that the values of the linear regression coefficients are never too big, even at the lowest values of Lambda. Therefore there is not a lot of overfitting. Therefore we can move forward to model using Ridge regression using the smallest Lambda:

# %%
ridge_w = Ridge(alpha=.0001, fit_intercept=True, normalize=True,random_state=0).fit(W_train_selected,w_train)

# %%
w_pred_ridge = ridge_w.predict(W_test_selected)

# %% [markdown]
# Train and predict using non-regularized linear regression on the selected features:

# %%
lr_w = LinearRegression(fit_intercept=True, normalize=True).fit(W_train_selected,w_train)

# %%
w_pred_lr = lr_w.predict(W_test_selected)

# %% [markdown]
# ### Let's plot the predictions for each model
#
# We start by making a dataframe so that we can line up the results:

# %%
W_results = W_test_selected.copy()

# %%
W_results['w_pred_lr'] = w_pred_lr
W_results['w_pred_ridge']= w_pred_ridge
W_results['w_pred_lasso'] = w_pred_lasso
W_results['WBdepth_sourceLocation'] = w_test

# %% [markdown]
# Note that there is degeneracy:

# %%
W_results.sort_values(by='sourceX').head(5)
# Out:
#     shot_number  sourceDepth  WBdepth_geophoneLocation   sourceX    sourceY  \
# 1          1596          6.1                       0.0  522201.4  6617307.4
# 2          1612          6.0                       0.0  522202.6  6617282.7
# 5          1660          5.9                       0.0  522206.9  6617207.4
# 8          1708          6.1                       0.0  522210.8  6617132.5
# 14         1804          6.0                       0.0  522218.9  6616982.8
#
#     streamerNumber  w_pred_lr  w_pred_ridge  w_pred_lasso  \
# 1                4  39.913716     39.030187     40.670463
# 2                4  38.964224     38.309256     39.445723
# 5                4  39.662801     38.556203     44.532381
# 8                4  42.767556     41.973870     46.163568
# 14               4  43.993548     43.412375     47.305149
#
#     WBdepth_sourceLocation
# 1                    37.80
# 2                    37.90
# 5                    38.20
# 8                    38.15
# 14                   38.42

# %% [markdown]
# #### To plot keyed off sx:

# %%
W_results_x = W_results.groupby(by='sourceX').first().reset_index()

# %%
plt.figure(figsize=(14,10))
plt.plot(W_results_x.sourceX,W_results_x.w_pred_lasso,'o',markersize=3)
#plt.plot(W_results_sx.sx,W_results_sx.w_pred_lr,'o', markersize=3)
#plt.plot(W_results_sx.sx,W_results_sx.w_pred_ridge,'o',markersize=3)
plt.plot(W_results_x.sourceX,W_results_x.WBdepth_sourceLocation,'*')
plt.title('modelling waterbottom with Lasso')
plt.xlabel('x-position of source')
plt.legend(['predicted','measured'],loc='upper left')

# %%
plt.figure(figsize=(14,10))
plt.plot(W_results_x.sourceX,W_results_x.w_pred_lr,'o', markersize=3)
plt.plot(W_results_x.sourceX,W_results_x.w_pred_ridge,'o',markersize=3)
plt.plot(W_results_x.sourceX,W_results_x.WBdepth_sourceLocation,'*')
plt.title('modelling waterbottom with linear regression and Ridge regression')
plt.xlabel('x-position of source')
plt.legend(['linear regression predicted','Ridge regression predicted','measured'],loc='upper left')

# %% [markdown]
# #### To plot keyed off sy

# %%
W_results_y = W_results.groupby(by='sourceY').first().reset_index()

# %%
plt.figure(figsize=(14,10))
plt.plot(W_results_y.sourceY,W_results_y.w_pred_lasso,'o',markersize=3)
#plt.plot(W_results_sx.sx,W_results_sx.w_pred_lr,'o', markersize=3)
#plt.plot(W_results_sx.sx,W_results_sx.w_pred_ridge,'o',markersize=3)
plt.plot(W_results_y.sourceY,W_results_y.WBdepth_sourceLocation,'*')
plt.title('modelling waterbottom with Lasso')
plt.xlabel('y-position of source')
plt.legend(['predicted','measured'],loc='upper left')

# %%
plt.figure(figsize=(14,10))
plt.plot(W_results_y.sourceY,W_results_y.w_pred_lr,'o', markersize=3)
plt.plot(W_results_y.sourceY,W_results_y.w_pred_ridge,'ob',markersize=3)
plt.plot(W_results_y.sourceY,W_results_y.WBdepth_sourceLocation,'*')
plt.title('modelling waterbottom with linear regression and Ridge regression')
plt.xlabel('y-position of source')
plt.legend(['linear regression predicted','Ridge regression predicted','measured'],loc='upper left')

# %% [markdown]
# #### To plot data key off shot number

# %%
W_results_shot = W_results.groupby('shot_number').first().reset_index()

# %%
W_results_shot.head()
# Out:
#    shot_number  sourceDepth  WBdepth_geophoneLocation   sourceX    sourceY  \
# 0         1596          6.1                       0.0  522201.4  6617307.4
# 1         1612          6.0                       0.0  522202.6  6617282.7
# 2         1660          5.9                       0.0  522206.9  6617207.4
# 3         1708          6.1                       0.0  522210.8  6617132.5
# 4         1804          6.0                       0.0  522218.9  6616982.8
#
#    streamerNumber  w_pred_lr  w_pred_ridge  w_pred_lasso  \
# 0               4  39.913716     39.030187     40.670463
# 1               4  38.964224     38.309256     39.445723
# 2               4  39.662801     38.556203     44.532381
# 3               4  42.767556     41.973870     46.163568
# 4               4  43.993548     43.412375     47.305149
#
#    WBdepth_sourceLocation
# 0                   37.80
# 1                   37.90
# 2                   38.20
# 3                   38.15
# 4                   38.42

# %%
plt.figure(figsize=(14,10))
plt.plot(W_results_shot.shot_number,W_results_shot.w_pred_lasso,'o',markersize=3)
#plt.plot(W_results_sx.sx,W_results_sx.w_pred_lr,'o', markersize=3)
#plt.plot(W_results_sx.sx,W_results_sx.w_pred_ridge,'o',markersize=3)
plt.plot(W_results_shot.shot_number,W_results_shot.WBdepth_sourceLocation,'*')
plt.title('modelling waterbottom with Lasso')
plt.xlabel('shot number of source')

plt.legend(['predicted','measured'],loc='upper left')

# %%
plt.figure(figsize=(14,10))
plt.plot(W_results_shot.shot_number,W_results_shot.w_pred_lr,'o', markersize=3)
plt.plot(W_results_shot.shot_number,W_results_shot.w_pred_ridge,'o',markersize=3)
plt.plot(W_results_shot.shot_number,W_results_shot.WBdepth_sourceLocation,'*')
plt.title('modelling waterbottom with linear and Ridge regression')
plt.xlabel('shot number of source')
plt.legend(['linear regression predicted','Ridge regression predicted','measured'],loc='upper left')

# %% [markdown]
# ## Using kNN linear regression
#
# We start by cross-validation to seek for the appropriate k. Given how irregular the ocean bottom, we expect this approach to give the best predictions.

# %%
knn_rss = []
for k in range(1,100,4):
    
    temp_rss = []
    
    for trainIndex, testIndex in kfolds.split(W_train_selected):
    
        knn_model = KNeighborsRegressor(n_neighbors=k,weights='distance').fit(W_train_selected.iloc[trainIndex],w_train.iloc[trainIndex])
        temp_rss.append(((w_train.iloc[testIndex] - knn_model.predict(W_train_selected.iloc[testIndex]))**2 ).sum())
    
    knn_rss.append(np.mean(temp_rss))

# %%
plt.figure(figsize=(14,7))
plt.plot(list(range(1,100,4)),knn_rss,'s')

# %%
knn_model_2 = KNeighborsRegressor(n_neighbors=2,weights='distance').fit(W_train_selected,w_train)
y_pred_knn2 = knn_model_2.predict(W_test_selected)

# %%
W_results_knn = W_test_selected.copy()
W_results_knn['WBdepth_sourceLocation']=w_test
W_results_knn['y_pred_knn2']= y_pred_knn2

# %%
W_results_knn = W_results_knn.groupby('shot_number').first().reset_index()
W_results_knn.head()
# Out:
#    shot_number  sourceDepth  WBdepth_geophoneLocation   sourceX    sourceY  \
# 0         1596          6.1                       0.0  522201.4  6617307.4
# 1         1612          6.0                       0.0  522202.6  6617282.7
# 2         1660          5.9                       0.0  522206.9  6617207.4
# 3         1708          6.1                       0.0  522210.8  6617132.5
# 4         1804          6.0                       0.0  522218.9  6616982.8
#
#    streamerNumber  WBdepth_sourceLocation  y_pred_knn2
# 0               4                   37.80    37.866409
# 1               4                   37.90    37.932438
# 2               4                   38.20    38.200293
# 3               4                   38.15    38.224777
# 4               4                   38.42    38.420000

# %%
plt.figure(figsize=(20,14))
plt.plot(W_results_knn.shot_number,W_results_knn.WBdepth_sourceLocation,"*")
plt.plot(W_results_knn.shot_number,W_results_knn.y_pred_knn2,'*')
plt.xlabel('shot number')
plt.ylabel('water bottom depth')
plt.title('Water bottom depth. Actual values and kNN-regression predictions.')
plt.legend(['measured ocean floor depth', 'predicted ocean floor depth'])

# %% [markdown]
# # Part 2: working with a swath of data acquisition

# %%
raw_data_2d = pd.read_csv('oneGun_oneCable_seismic_data_several_tracks.csv')

# %%
raw_data_2d.head()
# Out:
#    Unnamed: 0  channel_number  geophoneDepth  sourceDepth  geophoneDatum  \
# 0          78               1           11.1          6.1            0.0
# 1          79               1           11.0          6.1            0.0
# 2          80               1           10.9          6.1            0.0
# 3          81               1           10.7          6.1            0.0
# 4          82               1           10.6          6.0            0.0
#
#    sourceDatum  WBdepth_sourceLocation  WBdepth_geophoneLocation   sourceX  \
# 0          0.0                   63.13                     64.66  527000.4
# 1          0.0                   63.13                     64.66  527001.7
# 2          0.0                   63.58                     64.66  527002.8
# 3          0.0                   63.58                     62.89  527003.7
# 4          0.0                   63.58                     62.89  527004.5
#
#      sourceY  geophoneX  geophoneY  shipSpeed  day  hour  minute  sec  \
# 0  6597192.3   527163.4  6597134.0        248  264     3      26   19
# 1  6597217.6   527164.9  6597159.7        238  264     3      26   29
# 2  6597242.7   527166.3  6597185.3        239  264     3      26   40
# 3  6597267.9   527167.4  6597211.1        250  264     3      26   50
# 4  6597292.9   527168.5  6597236.7        251  264     3      27    0
#
#    shot_number  sequence_number      time
# 0         1157             1600  22821979
# 1         1159             1600  22821989
# 2         1161             1600  22822000
# 3         1163             1600  22822010
# 4         1165             1600  22822020

# %% [markdown]
# We plot the trajectory of the vessel, with a color scheme representing the speed of ship.

# %%
ax= plt.gca()
raw_data_2d.plot(x='sourceX',y='sourceY',kind='scatter',c='shipSpeed',colormap='viridis',ax=ax,figsize=(15,10),title='Trajectory and speed of vessel')

# %% [markdown]
# Now we plot the measured ocean bottom depth along the vessel's route. This quantity is hte one we will focus on and model below.

# %%
ax= plt.gca()
raw_data_2d.plot(x='sourceX',y='sourceY',kind='scatter',c='WBdepth_sourceLocation',colormap='viridis',ax=ax,figsize=(15,10),title='Map of ocean bottom depth (along vessel\'s path)')

# %% [markdown]
# Let's create only one attribute of time by combining: day, hour, minute, second.

# %%
raw_data_2d['time'] = raw_data_2d['day']*24*60*60 + raw_data_2d['hour']*60*60 + raw_data_2d['minute']*60 + raw_data_2d['sec']

# %%
raw_data_2d.head(3)
# Out:
#    Unnamed: 0  channel_number  geophoneDepth  sourceDepth  geophoneDatum  \
# 0          78               1           11.1          6.1            0.0
# 1          79               1           11.0          6.1            0.0
# 2          80               1           10.9          6.1            0.0
#
#    sourceDatum  WBdepth_sourceLocation  WBdepth_geophoneLocation   sourceX  \
# 0          0.0                   63.13                     64.66  527000.4
# 1          0.0                   63.13                     64.66  527001.7
# 2          0.0                   63.58                     64.66  527002.8
#
#      sourceY  geophoneX  geophoneY  shipSpeed  day  hour  minute  sec  \
# 0  6597192.3   527163.4  6597134.0        248  264     3      26   19
# 1  6597217.6   527164.9  6597159.7        238  264     3      26   29
# 2  6597242.7   527166.3  6597185.3        239  264     3      26   40
#
#    shot_number  sequence_number      time
# 0         1157             1600  22821979
# 1         1159             1600  22821989
# 2         1161             1600  22822000

# %% [markdown]
# Note that the sourceDatum, geophoneDatum, and channel number are constant valued, so we will drop them.

# %%
print(raw_data_2d.sourceDatum.min() == raw_data_2d.sourceDatum.max())
print(raw_data_2d.geophoneDatum.min() == raw_data_2d.geophoneDatum.max())
print(raw_data_2d.channel_number.min() == raw_data_2d.channel_number.max())
# Out:
# True
# True
# True

# %%
#dropping irrelevant columns. We have the new time attribute so we drop the rest as well.
relevant_data_2 = raw_data_2d.drop(['day','geophoneDatum','sourceDatum','hour','minute','sec','channel_number'],axis=1)
relevant_data_2['shotSequence'] = relevant_data['shot_number'] + relevant_data['sequence_number']* 10000

# %% [markdown]
# ## Modeling WBdepth_sourceLocation (water bottom depth at source)

# %% [markdown]
# #### We will create an instance of KFold to create different training/validation sets

# %%
kfolds = KFold(n_splits=10,shuffle=True,random_state=0)

# %% [markdown]
# #### We use LASSO to do feature selection

# %%
relevant_data_2.columns
# Out:
# Index(['Unnamed: 0', 'geophoneDepth', 'sourceDepth', 'WBdepth_sourceLocation',
#        'WBdepth_geophoneLocation', 'sourceX', 'sourceY', 'geophoneX',
#        'geophoneY', 'shipSpeed', 'shot_number', 'sequence_number', 'time',
#        'shotSequence'],
#       dtype='object')

# %%
waterDepthAttributes = ['geophoneDepth', 'sourceDepth',
       'WBdepth_geophoneLocation', 'sourceX', 'sourceY', 'geophoneX',
       'geophoneY', 'shipSpeed', 'shot_number', 'sequence_number', 'time','shotSequence']

# %%
X_train, X_test, y_train, y_test = train_test_split(relevant_data_2[waterDepthAttributes],relevant_data_2['WBdepth_sourceLocation'],random_state=0)

# %%
alpha_rss_lasso = []

for Alpha in np.logspace(-3,2,10):
    
    temp_rss = []
    for trainIndex, valIndex in kfolds.split(X_train):
        
        model_temp = Lasso(alpha=Alpha, fit_intercept=True, normalize=True, random_state=0).fit(X_train.iloc[trainIndex],y_train.iloc[trainIndex])
        y_pred_temp = model_temp.predict(X_train.iloc[valIndex])
        temp_rss.append( ((y_pred_temp - y_train.iloc[valIndex])**2).sum() )
    
        if list(np.nonzero(model_temp.coef_)[0]) and Alpha > 0.001:
            print('At alpha =', Alpha, 'nonzero coefficients are:')
            print(list(np.nonzero(model_temp.coef_)[0]))
        
    alpha_rss_lasso.append(np.mean(temp_rss))
# Out:
# /Users/cabrera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/cabrera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/cabrera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/cabrera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/cabrera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/cabrera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/cabrera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/cabrera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/cabrera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/cabrera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# At alpha = 0.003593813663804626 nonzero coefficients are:
# [2, 4, 5, 6, 7, 10]
# At alpha = 0.003593813663804626 nonzero coefficients are:
# [2, 4, 5, 6, 7, 10]
# At alpha = 0.003593813663804626 nonzero coefficients are:
# [2, 4, 5, 6, 7, 10]
# At alpha = 0.003593813663804626 nonzero coefficients are:
# [2, 4, 5, 6, 7, 10]
# At alpha = 0.003593813663804626 nonzero coefficients are:
# [2, 4, 5, 6, 7, 10]
# At alpha = 0.003593813663804626 nonzero coefficients are:
# [2, 4, 5, 6, 7, 10]
# At alpha = 0.003593813663804626 nonzero coefficients are:
# [2, 4, 5, 6, 7, 10]
# At alpha = 0.003593813663804626 nonzero coefficients are:
# [2, 4, 5, 6, 7, 10]
# At alpha = 0.003593813663804626 nonzero coefficients are:
# [2, 4, 5, 6, 7, 10]
# At alpha = 0.003593813663804626 nonzero coefficients are:
# [2, 4, 5, 6, 7, 10]
# At alpha = 0.01291549665014884 nonzero coefficients are:
# [4]
# At alpha = 0.01291549665014884 nonzero coefficients are:
# [4]
# At alpha = 0.01291549665014884 nonzero coefficients are:
# [4]
# At alpha = 0.01291549665014884 nonzero coefficients are:
# [4]
# At alpha = 0.01291549665014884 nonzero coefficients are:
# [4]
# At alpha = 0.01291549665014884 nonzero coefficients are:
# [4]
# At alpha = 0.01291549665014884 nonzero coefficients are:
# [4]
# At alpha = 0.01291549665014884 nonzero coefficients are:
# [4]
# At alpha = 0.01291549665014884 nonzero coefficients are:
# [4]
# At alpha = 0.01291549665014884 nonzero coefficients are:
# [4]

# %%
plt.figure(figsize=(7,7))
plt.plot(np.logspace(-2,4,10), alpha_rss_lasso)
plt.xlim(-.1,1)
# Out:
# (-0.1, 1)

# %%
selectedAttributes_2 = ['WBdepth_geophoneLocation', 'sourceX', 'sourceY', 'geophoneX',
       'geophoneY', 'shipSpeed', 'time','shotSequence']

# %% [markdown]
# ## Ridge regression with selected attributes

# %%
X_train_selected = X_train[selectedAttributes_2].copy()
X_test_selected = X_test[selectedAttributes_2].copy()

# %%
ridge_w_RSS = []
for Lambda in np.logspace(-4,2):
    
    temp_rss = []
    
    for trainIndex, testIndex in kfolds.split(X_train_selected):
    
        ridge = Ridge(alpha=Lambda, fit_intercept=True, normalize=True,random_state=0).fit(X_train_selected.iloc[trainIndex],y_train.iloc[trainIndex])
        temp_rss.append(((y_train.iloc[testIndex] - ridge.predict(X_train_selected.iloc[testIndex]))**2 ).sum())
    
    ridge_w_RSS.append(np.mean(temp_rss))

# %%
plt.figure(figsize=(7,7))
plt.plot(np.logspace(-4,2), ridge_w_RSS)

# %% [markdown]
# Let's look at the path of coefficients

# %%
ridge_coeff = []
for Lambda in np.logspace(-4,2):
    ridge =  Ridge(alpha=Lambda, fit_intercept=True, normalize=True,random_state=0).fit(X_train_selected.iloc[trainIndex],y_train.iloc[trainIndex])
    ridge_coeff.append(ridge.coef_)
    
ridge_coeff_path = np.array(ridge_coeff).transpose()

plt.figure(figsize=(10,5))
for x in range(5):
    plt.plot(np.logspace(-3,2),ridge_coeff_path[x])
plt.ylim(0,0.05)
plt.xlim(0,50)
plt.title('coefficients path')
plt.xlabel('lambda')
plt.ylabel('coefficient value')
# Out:
# Text(0, 0.5, 'coefficient value')

# %% [markdown]
# We can see from the above plots that the values of the linear regression coefficients are never too big, even at the lowest values of Lambda. Therefore there is not a lot of overfitting. Therefore we can move forward to model using Ridge regression using the smallest Lambda:

# %%
ridge_1 = Ridge(alpha=.0001, fit_intercept=True, normalize=True,random_state=0).fit(X_train_selected,y_train)
y_pred_ridge = ridge_1.predict(X_test_selected)

# %% [markdown]
# ## Let's plot the result

# %%
regression_results = X_test_selected.copy()
regression_results['WBdepth_sourceLocation'] = y_test
regression_results['y_pred_ridge'] = y_pred_ridge

# %%
ax = plt.gca()
regression_results.plot(x='sourceX',y='sourceY',kind='scatter',c=y_pred_ridge,colormap='viridis',ax=ax,figsize=(15,10),title='Map of predicted ocean bottom depth (along vessel\'s path)')

# %%
ax=plt.gca()
regression_results.plot(x='sourceX',y='sourceY',kind='scatter',c='WBdepth_sourceLocation',colormap='viridis',ax=ax,figsize=(15,10),title='Map of measured ocean bottom depth  (along vessel\'s path)')

# %% [markdown]
# We see that even though not as granular as the actually measured values, the linear regression model does have the over all picture well captured.
#
# Let's plot the difference between the measured values and the respective regression predictions.

# %%
regression_results['regression_pred_difference'] = regression_results['WBdepth_sourceLocation'] - regression_results['y_pred_ridge']
ax= plt.gca()
regression_results.plot(x='sourceX',y='sourceY',c='regression_pred_difference',kind='scatter',colormap='seismic',figsize=(15,10),ax=ax,title='Difference between measured and predicted values. Ridge regression')

# %% [markdown]
# # Modeling via kNN linear regression

# %% [markdown]
# We first scan for the appropriate k value.

# %%
knn_rss = []
for k in range(1,100,4):
    
    temp_rss = []
    
    for trainIndex, testIndex in kfolds.split(X_train_selected):
    
        knn_model_temp = KNeighborsRegressor(n_neighbors=k,weights='distance').fit(X_train_selected.iloc[trainIndex],y_train.iloc[trainIndex])
        temp_rss.append(((y_train.iloc[testIndex] - knn_model_temp.predict(X_train_selected.iloc[testIndex]))**2 ).sum())
    
    knn_rss.append(np.mean(temp_rss))
    
plt.figure(figsize=(14,7))
plt.plot(list(range(1,100,4)),knn_rss,'s')
plt.xlim(-1,50)
# Out:
# (-1, 50)

# %% [markdown]
# Let's zoom in:

# %%
knn_rss_small = []
for k in range(1,20,1):
    
    temp_rss = []
    
    for trainIndex, testIndex in kfolds.split(X_train_selected):
    
        knn_model_temp = KNeighborsRegressor(n_neighbors=k,weights='distance').fit(X_train_selected.iloc[trainIndex],y_train.iloc[trainIndex])
        temp_rss.append(((y_train.iloc[testIndex] - knn_model_temp.predict(X_train_selected.iloc[testIndex]))**2 ).sum())
    
    knn_rss_small.append(np.mean(temp_rss))

plt.figure(figsize=(14,7))
plt.plot(list(range(1,20,1)),knn_rss_small,'s')

# %% [markdown]
# __We will use k = 4.__

# %%
knn_model_4 = KNeighborsRegressor(n_neighbors=4,weights='distance').fit(X_train_selected,y_train)
y_pred_knn4 = knn_model_4.predict(X_test_selected)

# %% [markdown]
# Let's create a plot with the knn predictions:

# %%
regression_results['y_pred_knn4'] = y_pred_knn4

# %%
ax= plt.gca()
regression_results.plot(x='sourceX',y='sourceY',c='y_pred_knn4',kind='scatter',colormap='viridis',figsize=(15,10),ax=ax,title='Map of ocean bottom depth (along vessel\'s path) predicted by kNN')

# %% [markdown]
# Let's plot the difference:

# %%
regression_results['kNN_pred_difference'] = regression_results['WBdepth_sourceLocation'] - regression_results['y_pred_knn4']

# %%
regression_results['kNN_pred_difference'].min()
# Out:
# -6.99115739725714

# %%
ax= plt.gca()
regression_results.plot(x='sourceX',y='sourceY',c='kNN_pred_difference',kind='scatter',colormap='seismic',figsize=(15,10),ax=ax,title='Map of ocean bottom depth (along vessel\'s path) predicted by kNN')

# %% [markdown]
# # Interpretation

# %% [markdown]
# Whether to use kNN regression or Ridge linear regression depends on the density in the xy-plane of the values we are trying the predict.
#
# If the missing values are sparse, we should use the kNN approach since it can capture the finer details of the ocean bottom better provided we have enough data to model.
#
# On the other hand, if the missing values of the ocean depth a more densely located, for example, trying to predict a long portion of a group of sail lines (segments of the ship path), then the kNN would not give better results. The lack of neighbors in the region would make predictions based on constant values coming from polling the points far away. Then we should rely on the linear regression model because it has a longer wavelength.
